# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import glob, os

def extract_label(img_path):
    filename, _ = os.path.splitext(os.path.basename(img_path))
    
    subject_id, etc = filename.split('__')
    gender, lr, finger, _ = etc.split('_')
    
    gender = 0 if gender == 'M' else 1
    lr = 0 if lr =='Left' else 1
    
    if finger == 'thumb':
        finger = 0
    elif finger == 'index':
        finger = 1
    elif finger == 'middle':
        finger = 2
    elif finger == 'ring':
        finger = 3
    elif finger == 'little':
        finger = 4
        
    return np.array([subject_id, gender, lr, finger], dtype=np.uint16)

def extract_label2(img_path):
    
    filename, _ = os.path.splitext(os.path.basename(img_path))
    
    subject_id, etc = filename.split('__')
    gender, lr, finger, _, _ = etc.split('_')
    
    gender = 0 if gender == 'M' else 1
    lr = 0 if lr =='Left' else 1
    
    if finger == 'thumb':
        finger = 0
    elif finger == 'index':
        finger = 1
    elif finger == 'middle':
        finger = 2
    elif finger == 'ring':
        finger = 3
    elif finger == 'little':
        finger = 4
        
    return np.array([subject_id, gender, lr, finger], dtype=np.uint16)

datapaths = {'real':'SOCOFing/Real/*.BMP',
            'easy':'SOCOFing/Altered/Altered-Easy/*.BMP',
            'medium':'SOCOFing/Altered/Altered-Medium/*.BMP',
            'hard':'SOCOFing/Altered/Altered-Hard/*.BMP'}

for key, path in datapaths.items():
    img_list = sorted(glob.glob(path))
    # print(len(img_list))

    imgs = np.empty((len(img_list), 96, 96), dtype=np.uint8)
    labels = np.empty((len(img_list), 4), dtype=np.uint16)

    for i, img_path in enumerate(img_list):
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (96, 96))
        imgs[i] = img
        
        if key in 'real':
            # subject_id, gender, lr, finger
            labels[i] = extract_label(img_path)
        elif key in 'easy, medium, hard':
            labels[i] = extract_label2(img_path)
        
    np.savez('dataset/x_{}.npz'.format(key), data=imgs)
    np.save('dataset/y_{}.npy'.format(key), labels)

    plt.figure(figsize=(1, 1))
    plt.title(labels[-1])
    plt.imshow(imgs[-1], cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11228\604598130.py in <module>
#      72             labels[i] = extract_label2(img_path)
#      73
# ---> 74     np.savez('dataset/x_{}.npz'.format(key), data=imgs)
#      75     np.save('dataset/y_{}.npy'.format(key), labels)
#      76
#
# <__array_function__ internals> in savez(*args, **kwargs)
#
# ~\anaconda3\envs\ai37\lib\site-packages\numpy\lib\npyio.py in savez(file, *args, **kwds)
#     616
#     617     """
# --> 618     _savez(file, args, kwds, False)
#     619
#     620
#
# ~\anaconda3\envs\ai37\lib\site-packages\numpy\lib\npyio.py in _savez(file, args, kwds, compress, allow_pickle, pickle_kwargs)
#     713         compression = zipfile.ZIP_STORED
#     714
# --> 715     zipf = zipfile_factory(file, mode="w", compression=compression)
#     716
#     717     for key, val in namedict.items():
#
# ~\anaconda3\envs\ai37\lib\site-packages\numpy\lib\npyio.py in zipfile_factory(file, *args, **kwargs)
#     110     import zipfile
#     111     kwargs['allowZip64'] = True
# --> 112     return zipfile.ZipFile(file, *args, **kwargs)
#     113
#     114
#
# ~\anaconda3\envs\ai37\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1238             while True:
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
#    1241                 except OSError:
#    1242                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/x_real.npz'
